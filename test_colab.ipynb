# %%
import numpy as np

# %%
print(np.random.randint(10, size=(5,)))
# Out:
# [8 1 5 5 5]

# %%
print("Comment")
# Out:
# Comment

# %%
! wget https://raw.githubusercontent.com/GrigorievDmitry/colab_integration/master/external.py
# Out:
# --2020-03-07 16:05:46--  https://raw.githubusercontent.com/GrigorievDmitry/colab_integration/master/external.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 298 [text/plain]
# Saving to: ‘external.py’
#
# external.py         100%[===================>]     298  --.-KB/s    in 0s
#
# 2020-03-07 16:05:46 (43.5 MB/s) - ‘external.py’ saved [298/298]

# %%
from external import grader

# %%
grader(1, 12345)
# Out:
# 'ZzzZZZzzzz'

# %%
grader(1, 23456)
# Out:
# 'Station responding!'
